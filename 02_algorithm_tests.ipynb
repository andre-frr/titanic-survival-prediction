# %%
# 1. Import de bibliotecas e modelos

# Bibliotecas
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Modelos
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

RANDOM_STATE = 42
MAX_ITER = 1000

# %%
# 2. Carregar Dataset limpo e separar
df = pd.read_csv('./data/Titanic-Dataset-Clean.csv')
X = df.drop(columns=['Survived'])
y = df['Survived']

print(X.head())
print('-----------------------')
print(y.head())
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare
# 0       3    0  22.0      1      0   7.2500
# 1       1    1  38.0      1      0  71.2833
# 2       3    1  26.0      0      0   7.9250
# 3       1    1  35.0      1      0  53.1000
# 4       3    0  35.0      0      0   8.0500
# -----------------------
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
# 3. Testar os algoritmos

# Dividir os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)

# Normalizar os dados (importante para KNN e MLP)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Definir os algoritmos
modelos = {
    'LR': LogisticRegression(max_iter=MAX_ITER, random_state=RANDOM_STATE),
    'KNN': KNeighborsClassifier(),
    'MLP': MLPClassifier(max_iter=MAX_ITER, random_state=RANDOM_STATE),
    'DT': DecisionTreeClassifier(random_state=RANDOM_STATE),
    'RF': RandomForestClassifier(random_state=RANDOM_STATE),
    'NB': GaussianNB(),
}


# Treinar e avaliar
def avaliar_modelos(X_train, X_test, y_train, y_test):
    resultados = []
    for nome, modelo in modelos.items():
        # Treinar
        modelo.fit(X_train, y_train)
        # Prever
        previsoes = modelo.predict(X_test)
        # Avaliar
        acc = accuracy_score(y_test, previsoes)
        resultados.append((nome, acc))

    # Ordenar do melhor para o pior
    resultados.sort(key=lambda x: x[1], reverse=True)
    return resultados


# Executar e comparar
results = avaliar_modelos(X_train_scaled, X_test_scaled, y_train, y_test)
print("Desempenho dos Modelos (Accuracy):")
for nome, acc in results:
    print(f"{nome}: {acc:.2%}")
# Out:
# Desempenho dos Modelos (Accuracy):
# MLP: 81.01%
# RF: 80.45%
# LR: 79.89%
# KNN: 78.77%
# NB: 77.09%
# DT: 75.98%
